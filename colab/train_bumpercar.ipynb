# %% [markdown]
# # Train bumpercar controller
#
# Minimal notebook for running the existing `experiments/robots/run.py` script in Colab or locally.

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB

# %%
from pathlib import Path
import os

os.listdir("/content")
# os.getcwd()
# Out:
# ['.config', 'sample_data']

# %%
os.chdir("/content")

# %%
# !mv arg_parser.py /content/reference_tracking_PB/experiments/robots/arg_parser.py
#

# %%
# !unzip /content/reference_tracking_PB.zip -d /content
# Out:
# Archive:  /content/reference_tracking_PB.zip
#    creating: /content/reference_tracking_PB/
#   inflating: /content/reference_tracking_PB/.DS_Store
#   inflating: /content/reference_tracking_PB/config.py
#    creating: /content/reference_tracking_PB/loss_functions/
#    creating: /content/reference_tracking_PB/plants/
#    creating: /content/reference_tracking_PB/experiments/
#    creating: /content/reference_tracking_PB/utils/
#    creating: /content/reference_tracking_PB/__pycache__/
#   inflating: /content/__MACOSX/reference_tracking_PB/.___pycache__
#   inflating: /content/reference_tracking_PB/README.md
#   inflating: /content/reference_tracking_PB/setup.py
#   inflating: /content/reference_tracking_PB/.gitignore
#    creating: /content/reference_tracking_PB/colab/
#    creating: /content/reference_tracking_PB/.git/
#    creating: /content/reference_tracking_PB/.vscode/
#   inflating: /content/__MACOSX/reference_tracking_PB/._.vscode
# ...

# %%
os.chdir("/content/reference_tracking_PB/")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python experiments/robots/run.py \
  --epochs 200 \
  --num-rollouts 300 \
  --batch-size 50 \
  --log-epoch 5 \
  --lr 1e-03 \
  --save-path /content/drive/MyDrive/bumpercar_saved_results
# Out:
# [INFO] GPU available
#
# [INFO] Dataset: n_agents: 2 -- num_rollouts: 300 -- std_ini: 0.20 -- time horizon: 100
# [INFO] Plant: spring constant: 1.00 -- use linearized plant: False
# [INFO] Controller: dimension of the internal state: 8 -- dim_nl: 8 -- cont_init_std: 0.10
# [INFO] Loss:  alpha_u: 0.000250 -- alpha_col: 500 -- alpha_obst: 10000.0
# [INFO] Optimizer: lr: 1.00e-03 -- batch_size: 50, -- return best model for validation data among logged epochs:True
# Plotting closed-loop trajectories with PID only...
# Plotting closed-loop trajectories before training the controller...
#
# ------------ Begin training ------------
# Epoch: 0 --- train loss: 1072.10 ---||--- validation loss: 1215.10 (best so far) ---||--- time: 33 s
# Epoch: 5 --- train loss: 1068.28 ---||--- validation loss: 930.82 (best so far) ---||--- time: 159 s
# Epoch: 10 --- train loss: 638.90 ---||--- validation loss: 505.69 (best so far) ---||--- time: 160 s
# ...
